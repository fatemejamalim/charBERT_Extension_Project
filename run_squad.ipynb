# %%
! python ./CharBERT/run_squad.py \
    --model_type bert \
    --model_name_or_path "./model/output/general/MLM_cased/wiki_eng" \
    --do_train \
    --do_eval \
    --data_dir  "/Users/mohammadakbari/WorkspaceM/Z_prj/NLP/FinalProject/nlp-project/datasets" \
    --train_file "squad/train-v2.0.json" \
    --predict_file "squad/dev-v2.0.json" \
    --char_vocab "./CharBERT/data/dict/bert_char_vocab" \
    --learning_rate 5e-5 \
    --num_train_epochs 2 \
    --save_steps 5000 \
    --max_seq_length 384 \
    --overwrite_output_dir \
    --doc_stride 128 \
    --output_dir "./model/output/medical/squad/"
# Out:
# 07/15/2024 17:30:48 - WARNING - __main__ -   Process rank: -1, device: cpu, n_gpu: 0, distributed training: False, 16-bits training: False
# 07/15/2024 17:30:48 - INFO - modeling.configuration_utils -   loading configuration file ./model/output/general/MLM_cased/wiki_eng/config.json
# 07/15/2024 17:30:48 - INFO - modeling.configuration_utils -   Model config {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
# ...
